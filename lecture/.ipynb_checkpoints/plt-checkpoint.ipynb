# %%
# %matplotlib inline
import cv2
import pafy
import youtube_dl as yt
import matplotlib.pyplot as mpl
import numpy as np

# %%
cap = cv2.VideoCapture(0)
cap.set(3,600)
cap.set(4,800)

while(True):
    ret, frame = cap.read()
    
    # 좌우 뒤집기
    frame = cv2.flip(frame, 1)
    cv2.imshow('background', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        back = frame[100:-1, 250:800]
        break
# Out:
# '4.1.0'

# %%
img = mpl.imread('C:\\Users\\김민수\\Desktop\\다운로드.jpg')
mpl.imshow(img)

# %%
img.flags.writeable = 1
img[:200,:300,:] = 1 - img[:200,:300,:]

# %%
mpl.imshow(img)
